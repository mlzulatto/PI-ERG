# %% [markdown]
# Yo creo que es mejor esa representacion ya que el eje x repterentaria los grupos o etiquetas, y las barras de colores el porcentaje de kluster que pertenece.
# el 100% se da sumando las barras de un mismo grupo
#
# pendiente:
# Ver como ponerlo en porcentaje al eje Y,
# agregar titulo con grupo perteneciente y modelo.
# meter e un for para que haga el grafico de todos
# Ver si hay algo mas interesante para agregarle .

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#Creo lista de los nombres de las ojas del excel
list_sheet_names = pd.ExcelFile('C:/Users/toto_/PYTHON_TESIS/unsuppervised_models_outputs_Normalizados 3.xlsx')
list_sheet_names = list_sheet_names.sheet_names
type(list_sheet_names)
# Out:
# list

# %%
for n_sheet in list_sheet_names:
    df = pd.read_excel("unsuppervised_models_outputs_Normalizados 3.xlsx", sheet_name= n_sheet , index_col=0)
    dfT=df.T

    #ax = df.plot.bar(rot=0)
    graph = df.plot.bar(rot=0,figsize=(10,5), title="Modelo+df=  "+n_sheet, xlabel="Etiquetas", ylabel="% de predicciones por Cluster",grid=True)
    
    spath = "C:/Users/toto_/PYTHON_TESIS/GRAFICOS DE BARRA/GRAFICOS DE BARRA NO SUPERVISADO 3 ETIQ"
    plt.savefig(spath+"/"+str(n_sheet)+".jpg")

# %% [markdown]
# for n_sheet in list_sheet_names:
#     df = pd.read_excel("matriz_confusion_3.xlsx", sheet_name= n_sheet , index_col=0)
#
#     fig = plt.figure(figsize =(8, 5))
#     fig.set_figwidth
#     for columns in df.columns:
#         plt.bar(df.index.values, (df[columns].values)*100,width=0.35, label="Cluster" + str(columns))
#         plt.xticks(df.index.values)
#         plt.title("Modelo+df=  "+n_sheet)
#         plt.xlabel("Etiquetas")
#         plt.ylabel("Porcentaje de predicciones por Cluster [%]" )
#     plt.legend()
#     plt.grid()
#
#
#     spath = "C:/Users/toto_/PYTHON_TESIS/GRAFICOS DE BARRA/GRAFICOS DE BARRA NO SUPERVISADO 3 ETIQ"
#     plt.savefig(spath+"/"+str(n_sheet)+".jpg")

# %%
#Creo lista de los nombres de las ojas del excel
list_sheet_names = pd.ExcelFile('C:/Users/toto_/PYTHON_TESIS/unsuppervised_models_outputs_Normalizados 8.xlsx')
list_sheet_names = list_sheet_names.sheet_names
type(list_sheet_names)
# Out:
# list

# %% [markdown]
# for n_sheet in list_sheet_names:
#     df = pd.read_excel("matriz_confusion_8.xlsx", sheet_name= n_sheet , index_col=0)
#
#     fig = plt.figure(figsize =(15, 10))
#     fig.set_figwidth
#     for columns in df.columns:
#         plt.bar(df.index.values, (df[columns].values)*100, width=0.35, label="Cluster" + str(columns))
#         plt.xticks(df.index.values)
#         plt.title("Modelo+df=  "+n_sheet)
#         plt.xlabel("Etiquetas")
#         plt.ylabel("Porcentaje de predicciones por Cluster [%]" )
#     plt.legend()
#     plt.grid()
#
#
#     #spath = "C:/Users/toto_/PYTHON_TESIS/GRAFICOS DE BARRA/GRAFICOS DE BARRA NO SUPERVISADO 8 ETIQ"
#     #plt.savefig(spath+"/"+str(n_sheet)+".jpg")

# %% [markdown]
# #Creo lista de los nombres de las ojas del excel
# list_sheet_names = pd.ExcelFile('C:/Users/toto_/PYTHON_TESIS/unsuppervised_models_outputs_Normalizados 8.xlsx')
# list_sheet_names = list_sheet_names.sheet_names
# type(list_sheet_names)

# %%
for n_sheet in list_sheet_names:
    df = pd.read_excel("unsuppervised_models_outputs_Normalizados 8.xlsx", sheet_name= n_sheet , index_col=0)
    dfT=df.T

    #ax = df.plot.bar(rot=0)
    graph = df.plot.bar(rot=0,figsize=(15,10), title="Modelo+df=  "+n_sheet, xlabel="Etiquetas", ylabel="% de predicciones por Cluster",grid=True)
    
    spath = "C:/Users/toto_/PYTHON_TESIS/GRAFICOS DE BARRA/GRAFICOS DE BARRA NO SUPERVISADO 8 ETIQ"
    plt.savefig(spath+"/"+str(n_sheet)+".jpg")
